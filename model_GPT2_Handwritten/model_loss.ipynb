# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dict_loss = [
    {'step': 500, 'Training Loss': 19.82, "Validation Loss": 19.43},
    {'step': 1000, "Training Loss": 7.433, 'Validation Loss': 6.72},
    {'step': 1500, "Training Loss": 1.791, "Validation Loss": 2.398}, 
    {'step': 2000, "Training Loss": 1.547, "Validation Loss": 2.1398},
    {'step': 2500, "Training Loss": 1.502, "Validation Loss": 2.098},
    {'step': 3000, "Training Loss": 1.473, "Validation Loss": 2.081},
    {'step': 3500, 'Training Loss': 1.421, 'Validation Loss': 2.072},
    {'step': 4000, 'Training Loss': 1.4346, 'Validation Loss': 2.0645},
    {'step': 5000, 'Training Loss': 1.442, 'Validation Loss': 2.0619},
    {'step': 5500, 'Training Loss': 1.418, 'Validation Loss': 2.0582},
    {'step': 5500, 'Training Loss': 1.424, 'Validation Loss': 2.0562}
]

data = pd.DataFrame(dict_loss)

data
# Out:
#     step  Training Loss  Validation Loss
# 0    500        19.8200          19.4300
# 1   1000         7.4330           6.7200
# 2   1500         1.7910           2.3980
# 3   2000         1.5470           2.1398
# 4   2500         1.5020           2.0980
# 5   3000         1.4730           2.0810
# 6   3500         1.4210           2.0720
# 7   4000         1.4346           2.0645
# 8   5000         1.4420           2.0619
# 9   5500         1.4180           2.0582
# 10  5500         1.4240           2.0562

# %%
plt.plot(data['step'], data['Validation Loss'])
plt.plot(data['step'], data['Training Loss'])
plt.ylabel('Loss')
plt.xlabel('Step')
plt.title('Loss for Fintuning of GPT2 on Handwritten Data')
# Out:
# Text(0.5, 1.0, 'Loss for Fintuning of GPT2 on Handwritten Data')
